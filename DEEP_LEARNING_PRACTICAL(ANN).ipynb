# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.4
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.2.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      21.3.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.0
# arviz                            0.15.1
# astropy                          5.2.2
# astunparse                       1.6.3
# async-timeout                    4.0.2
# attrs                            23.1.0
# audioread                        3.0.0
# autograd                         1.6.2
# Babel                            2.12.1
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# ...

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/sagnikghoshcr7/Bank-Customer-Churn-Prediction/master/Churn_Modelling.csv")
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df= pd.read_csv("https://raw.githubusercontent.com/sagnikghoshcr7/Bank-Customer-Churn-Prediction/master/Churn_Modelling.csv")

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'],inplace = True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
pd.get_dummies(df,columns=["Geography", "Gender"],drop_first=True)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %%
df =pd.get_dummies(df,columns=["Geography", "Gender"],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
df.drop(["Exited"],axis = 1)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %%
X = df.drop(["Exited"],axis = 1)

# %%
y = df["Exited"]

# %%
import tensorflow
from tensorflow import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
len(X.columns)
# Out:
# 11

# %%
model = Sequential()
model.add(Dense(9,activation="sigmoid", input_dim=11))#input layer, 9 is for hidden layer
model.add(Dense(11,activation="sigmoid"))#hidden layer
model.add(Dense(1,activation="sigmoid"))#output layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 9)                 108
#
#  dense_4 (Dense)             (None, 11)                110
#
#  dense_5 (Dense)             (None, 1)                 12
#
# ...
# Total params: 230
# Trainable params: 230
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Dense(11,activation="sigmoid", input_dim=11))#input layer, 9 is for hidden layer
model.add(Dense(11,activation="sigmoid"))#hidden layer
model.add(Dense(1,activation="sigmoid"))#output layer

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 11)                132
#
#  dense_7 (Dense)             (None, 11)                132
#
#  dense_8 (Dense)             (None, 1)                 12
#
# ...
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

# %%
model.compile(optimizer="Adam", loss = "binary_crossentropy",metrics= ["accuracy"])

# %%
model.fit(X_train_scale,y_train,batch_size = 50,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 160/160 [==============================] - 6s 4ms/step - loss: 0.5327 - accuracy: 0.7960
# Epoch 2/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4860 - accuracy: 0.7960
# Epoch 3/10
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4725 - accuracy: 0.7960
# Epoch 4/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7960
# Epoch 5/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4493 - accuracy: 0.7960
# Epoch 6/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.7961
# Epoch 7/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.8031
# Epoch 8/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4311 - accuracy: 0.8102
# Epoch 9/10
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.8106
# Epoch 10/10
# ...

# %%
model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[0.42062098],
#        [0.42062098],
#        [0.42062098],
#        ...,
#        [0.42062098],
#        [0.50091475],
#        [0.42062098]], dtype=float32)

# %%
y_pred=model.predict(X_test_scale)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.22017288],
#        [0.37316847],
#        [0.14680998],
#        ...,
#        [0.15731026],
#        [0.11692332],
#        [0.197455  ]], dtype=float32)

# %%
y_pred=y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975
